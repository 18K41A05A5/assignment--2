# %% [markdown]
# 1. Given the length of three sides of a triangle,calculate the area of atrianle

# %%
a=float(input("enter length of first side:"))
b=float(input("enter length of second side:"))
c=float(input("enter length of thirdside:"))
if a+b>c:
    s=(a+b+c)/2
    area=(s*(s-a)*(s-b)*(s-c))**(1/2)
    print("area=",round(area,3))
else:
    print("Triangle is not possible")
# Out:
# enter length of first side:8
# enter length of second side:8
# enter length of thirdside:9
# area= 29.765

# %% [markdown]
# 2.Take a string from end user and check if the value is palindrom or not

# %%
s=input("enter string")
if s[::-1]==s:
  print("given string is a palindrom")
else:
  print("given string is not a palindrom")
# Out:
# enter stringdfghfd
# given string is not a palindrom

# %% [markdown]
# 3. Write a program that reads a year from the user and display a message indicating whether or not it is a leap year.

# %%
y=int(input("Enter year"))
if (y%12==4):
  print("given year is a leap year")
else:
  print("given year is not a leap year")
# Out:
# Enter year2020
# given year is aleap year

# %% [markdown]
# 4. Take a string as input , and replaces spaces " " with hyphens '-' and returns a string

# %%
s=input("Enter string")
s.replace(' ','-')
# Out:
# Enter stringThis program converts spaces to hypen
# 'This-program-converts-spaces-to-hypen'

# %% [markdown]
# 5.Take a string as input that accepts a comma separated sequence of words as input and prints the unique words in sorted form(alphanumerically)

# %%
str=input("Enter a string: ")
s=str.split()
s.sort()
a=list(s)
print(a)
# Out:
# Enter a string: orange,white,red,cyan,green,magenta,cyan,pink,white
# ['orange,white,red,cyan,green,magenta,cyan,pink,white']

# %% [markdown]
# 6. TAX CALCULATOR
# Ask the user for their monthly salary. calculate whether they have to pay the tax and if so,how much is that amount .print the result.

# %%
income=float(input("enter income"))
if income>0 and income<250000:
  tax=income*0
elif income>250001 and income<=500000:
  tax=income*0.05
elif (income>500001 and income<=750000):
  tax=income*0.1
elif (income>750001 and income<=1000000):
  tax=income*0.15
elif (income>1000001 and income<=1250000):
  tax=income*0.20
elif (income>1250001 and income<=1500000):
  tax=income*0.25
else:
  tax=income*0.30
print(tax)
# Out:
# enter income750000
# 75000.0

# %% [markdown]
# 7. Take a list of integers as a an argument,and converts it into a single integer (return the integer)

# %%
l=[11,33,50]
for i in l:
  print(i,end=" ")
# Out:
# 11 33 50

# %% [markdown]
# 8.UNITS OF TIME
# create a program that reads duration from the user as a number of days,hours,minutes,and seconds.compute and display the total number of seconds represented by this duration.

# %%
secpermin=60
secperhour=3600
secperday=86400
days=int(input("Enter no of days="))
hours=int(input("Enter no of hours="))
minutes=int(input("Enter no of minutess="))
seconds=int(input("Enter no of seconds="))
totsecs=days*secperday
totsecs=totsecs+(hours*secperhour)
totsecs=totsecs+(minutes*secperday)
totsecs=totsecs+seconds
print(totsecs)
# Out:
# Enter no of days=1
# Enter no of hours=1
# Enter no of minutess=0
# Enter no of seconds=0
# 90000

# %% [markdown]
# 9.given three integers (given through user input) ,sort the numbers using |min| and |max| functions.

# %% [markdown]
# ```
# `# This is formatted as code`
# ```

# %%
a=int(input("Enter the number of a:"))
b=int(input("Enter the number of b:"))
c=int(input("Enter the number of c:"))
d=min(a,b,c)
e=max(a,b,c)
f=(a+b+c)-d-e
print("The Sorted order is:",d,f,e)
# Out:
# Enter the number of a:1
# Enter the number of b:9
# Enter the number of c:3
# The Sorted order is: 1 3 9

# %% [markdown]
# 10.  Write a program that reads a date from the user and computes its immediate successor.The date is the format YYYY-MM-DD. So, 2020-04-15
#   will have the successor 2020-04-16.

# %%
year=int(input("enter year:"))
if year%400==0:
  leapyear=True
elif year%100==0:
  leapyear=False
elif year%4==0:
  leapyear=True
else:
  leapyear=False
month=int(input("enter a month from 1 to 12"))
if month in(1,3,5,7,8,10,12):
  monthlength=31
elif month==2:
  monthlength=29
else:
  monthlength=30
day=int(input("enter a day blw 1 to 31"))
if day<monthlength:
    day+=1
else:
    day=1
    if month==12:
        month=1
        year+=1
    else:
        month+=1
print("The immediate successor is YYYY-MM-DD : %d-%d-%d." %(year,month,day))
# Out:
# enter year:2020
# enter a month from 1 to 1210
# enter a day blw 1 to 3130
# The immediate successor is YYYY-MM-DD : 2020-10-31.
